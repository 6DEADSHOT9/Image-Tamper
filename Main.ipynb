# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import pandas as pd
import requests

# %%
original = pd.read_csv('Data\PS-Battles-master\PS-Battles-master\originals.tsv', sep='\t')
original[['url'],['']][13]
# Out:
# 'http://i.imgur.com/AEmpy.jpg'

# %%
tampered = pd.read_csv('Data\PS-Battles-master\PS-Battles-master\photoshops.tsv', sep='\t')
tampered['url']
# Out:
# 0        http://i.imgur.com/xIJ4z.png
# 1        http://i.imgur.com/2BooJ.jpg
# 2        http://i.imgur.com/Pt2Mc.png
# 3        http://i.imgur.com/OPe6n.png
# 4        http://i.imgur.com/EvP6W.jpg
#                      ...
# 90881    http://i.imgur.com/XL8zI.jpg
# 90882    http://i.imgur.com/dK59c.png
# 90883    http://i.imgur.com/6Rq9u.jpg
# 90884    http://i.imgur.com/QFIYU.jpg
# 90885    http://i.imgur.com/7YlIx.jpg
# Name: url, Length: 90886, dtype: object

# %%
tampered['url'][90882].split('/')[-1].split('.')[0]
# Out:
# 'dK59c'

# %%
image = requests.get(original['url'][13], stream=True).raw
image = np.asarray(bytearray(image.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
imgur_not_found = image
image = cv2.resize(image, (224, 224))
name = original['url'][13].split('/')[-1].split('.')[0]
print(name)
plt.imshow(image)
# cv2.imwrite('Data/'+ name + '.jpg', cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# Out:
# AEmpy

# %%
if image.all() == imgur_not_found.all():
    print('not found')

# %%
error_original = []
error_tampered = []
for i in range(len(original)):
    try:
        name = original['url'][i].split('/')[-1].split('.')[0]
        print(name)
        image = requests.get(original['url'][i], stream=True).raw
        image = np.asarray(bytearray(image.read()), dtype="uint8")
        image = cv2.imdecode(image, cv2.IMREAD_COLOR)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if image.all() == imgur_not_found.all():
            raise FileNotFoundError('The image you are requesting does not exist or is no longer available.')
        image = cv2.resize(image, (224, 224))
        cv2.imwrite('Data/PS-Battles-master/Images/original/'+ name + '.jpg', cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    except Exception as e:
        error_original.append([original['url'][i],str(e)])
        print(e)
        continue

for i in range(len(tampered)):
    try:
        name = tampered['url'][i].split('/')[-1].split('.')[0]
        print(name)
        image = requests.get(tampered['url'][i], stream=True).raw
        image = np.asarray(bytearray(image.read()), dtype="uint8")
        image = cv2.imdecode(image, cv2.IMREAD_COLOR)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if image.all() == imgur_not_found.all():
            raise FileNotFoundError('The image you are requesting does not exist or is no longer available.')
        image = cv2.resize(image, (224, 224))
        cv2.imwrite('Data/PS-Battles-master/Images/tampered/'+ name + '.jpg', cv2.cvtColor(image, cv2.COLOR_BGR2RGB))     
    except Exception as e:
        error_tampered.append([tampered['url'][i],str(e)])
        print(e)
        continue
# Out:
# qHxM2
# 9xndJ
# AFFHn
# ciycE
# yxLxO
# MzRVc
# Efmqy
# KSvoy
# 3m1jv
# JZEZ6
# cms0k
# jhDxh
# CVcx1
# AEmpy
# The image you are requesting does not exist or is no longer available.
# G4AKg
# UbKQE
# knRfm
# INBzM
# VR3oq
# VCKFP
# X5oVF
# bqWUE
# vmXTZ
# W2Wca
# nM0Ug
# rQS9j
# ifY2z
# 5rXid
# GGqLj
# i2AlC
# nOmJH
# AP120702135050
# HTTPConnectionPool(host='cdn.theatlanticwire.com', port=80): Max retries exceeded with url: /img/upload/2012/07/04/AP120702135050.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001870FC0CD00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 6dcrH
# 15dmO
# Iemri
# T3Qp7
# 4zyCX
# 8UzRq
# 2hdq5
# PErG6
# Cxagv
# Wq4qq
# AAZ67
# yWTw4
# Lsgd0
# QKA3G
# QWkU7
# PXdBC
# 3HUxJ
# zOAN0
# baird-crop
# ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# gLJau
# PzELc
# iZoSm
# 38Nzr
# sloth
# ...
